# %%
pip install yfinance
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import yfinance as yf
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

# %% [markdown]
# Major Cryptocurrency chosen:Binance Coin
#
# Two years Cryptocurrency Historical data

# %%
initial_data = yf.download("BNB-USD", start="2020-12-01", end="2022-12-01")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
initial_data.head()
# Out:
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2020-12-01  31.411509  31.871908  29.484135  30.108303  30.108303  467818960
# 2020-12-02  30.147505  30.910141  29.748901  30.297361  30.297361  371441750
# 2020-12-03  30.303986  30.769117  29.978310  30.704430  30.704430  324897560
# 2020-12-04  30.716002  31.116619  28.925531  29.072208  29.072208  362626786
# 2020-12-05  29.075138  30.002951  28.757483  29.729488  29.729488  307895991

# %%
initial_data.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-11-26  300.571747  316.962128  300.389465  311.388458  311.388458
# 2022-11-27  311.372040  316.219879  307.156372  307.429291  307.429291
# 2022-11-28  307.399567  309.096100  289.493683  293.527252  293.527252
# 2022-11-29  293.491821  304.822815  289.763641  295.498169  295.498169
# 2022-11-30  295.548218  304.650970  294.382263  300.794342  300.794342
#
#                 Volume
# Date
# 2022-11-26  1221554861
# 2022-11-27   793779029
# 2022-11-28  1154829072
# 2022-11-29   986451640
# 2022-11-30  1009620336

# %%
initial_data['Adj Close'].head()
# Out:
# Date
# 2020-12-01    30.108303
# 2020-12-02    30.297361
# 2020-12-03    30.704430
# 2020-12-04    29.072208
# 2020-12-05    29.729488
# Name: Adj Close, dtype: float64

# %%
data =  initial_data['Adj Close']
data.info()
# Out:
# <class 'pandas.core.series.Series'>
# DatetimeIndex: 730 entries, 2020-12-01 to 2022-11-30
# Series name: Adj Close
# Non-Null Count  Dtype
# --------------  -----
# 730 non-null    float64
# dtypes: float64(1)
# memory usage: 11.4 KB

# %%
data.head()
# Out:
# Date
# 2020-12-01    30.108303
# 2020-12-02    30.297361
# 2020-12-03    30.704430
# 2020-12-04    29.072208
# 2020-12-05    29.729488
# Name: Adj Close, dtype: float64

# %%
data.tail()
# Out:
# Date
# 2022-11-26    311.388458
# 2022-11-27    307.429291
# 2022-11-28    293.527252
# 2022-11-29    295.498169
# 2022-11-30    300.794342
# Name: Adj Close, dtype: float64

# %% [markdown]
# Plotting the movement of the CryptoCurrency

# %%
data.plot(figsize=(8, 5), subplots=True)
# Out:
# array([<AxesSubplot:xlabel='Date'>], dtype=object)

# %%
data.describe().round(2)
# Out:
# count    730.00
# mean     341.48
# std      146.46
# min       27.36
# 25%      271.82
# 50%      327.61
# 75%      424.86
# max      675.68
# Name: Adj Close, dtype: float64

# %%
initial_data = yf.download("BNB-USD", start="2021-09-01", end="2022-12-01")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
initial_data.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2021-09-01  464.272919  490.068726  455.758087  490.068726  490.068726
# 2021-09-02  489.859894  504.541260  480.036896  483.921051  483.921051
# 2021-09-03  483.756592  494.395203  475.225891  488.604706  488.604706
# 2021-09-04  488.407013  510.057648  485.856110  498.078430  498.078430
# 2021-09-05  497.704865  505.116699  489.474915  504.619873  504.619873
#
#                 Volume
# Date
# 2021-09-01  2303587593
# 2021-09-02  2324361979
# 2021-09-03  2051522050
# 2021-09-04  2310249697
# 2021-09-05  1899639214

# %%
initial_data['Adj Close'].head()
# Out:
# Date
# 2021-09-01    490.068726
# 2021-09-02    483.921051
# 2021-09-03    488.604706
# 2021-09-04    498.078430
# 2021-09-05    504.619873
# Name: Adj Close, dtype: float64

# %% [markdown]
# Extracting the Adjusted Close Column

# %%
data =  initial_data['Adj Close']
data.info()
# Out:
# <class 'pandas.core.series.Series'>
# DatetimeIndex: 456 entries, 2021-09-01 to 2022-11-30
# Series name: Adj Close
# Non-Null Count  Dtype
# --------------  -----
# 456 non-null    float64
# dtypes: float64(1)
# memory usage: 7.1 KB

# %%
data.head()
# Out:
# Date
# 2021-09-01    490.068726
# 2021-09-02    483.921051
# 2021-09-03    488.604706
# 2021-09-04    498.078430
# 2021-09-05    504.619873
# Name: Adj Close, dtype: float64

# %%
data.tail()
# Out:
# Date
# 2022-11-26    311.388458
# 2022-11-27    307.429291
# 2022-11-28    293.527252
# 2022-11-29    295.498169
# 2022-11-30    300.794342
# Name: Adj Close, dtype: float64

# %% [markdown]
# Calculating Annualised Volatility
#
# Plotting the Adjusted Close Column

# %%
data.plot(figsize=(8, 5), subplots=True)
# Out:
# array([<AxesSubplot:xlabel='Date'>], dtype=object)

# %%
data.describe().round(2)
# Out:
# count    456.00
# mean     377.27
# std      108.62
# min      197.04
# 25%      283.77
# 50%      372.46
# 75%      435.75
# max      654.32
# Name: Adj Close, dtype: float64

# %%
df=data[-91:-1]
df.head()
# Out:
# Date
# 2022-09-01    278.417236
# 2022-09-02    277.416107
# 2022-09-03    277.775574
# 2022-09-04    278.841858
# 2022-09-05    276.685913
# Name: Adj Close, dtype: float64

# %%
log_return = np.log(df / df.shift(1))
log_return
# Out:
# Date
# 2022-09-01         NaN
# 2022-09-02   -0.003602
# 2022-09-03    0.001295
# 2022-09-04    0.003831
# 2022-09-05   -0.007762
#                 ...
# 2022-11-25    0.000499
# 2022-11-26    0.035335
# 2022-11-27   -0.012796
# 2022-11-28   -0.046275
# 2022-11-29    0.006692
# Name: Adj Close, Length: 90, dtype: float64

# %%
fig = plt.figure()
plt.plot(log_return)
#plt.plot(log_return, np.maximum(S-0.2287))
plt.xlabel('Date')
plt.ylabel('log return')
plt.title('Log Return')
plt.show()

# %%
vol = np.sqrt(365) * log_return.std()
print('The annualised volatility is', round(vol*100,2), '%')
# Out:
# The annualised volatility is 71.39 %

# %%
df[-1]  #spot price
# Out:
# 295.4981689453125

# %% [markdown]
# Derivative

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as si
import yfinance as yf

# %% [markdown]
# Black Scholes Model

# %%
def euro_option_bs(S, K, T, r, vol, payoff):
    
    #S: spot price
    #K: strike price
    #T: time to maturity
    #r: interest rate
    #vol: volatility of underlying asset
    #payoff: call or put
    
    d1 = (np.log(S / K) + (r + 0.5 * vol ** 2) * T) / (vol * np.sqrt(T))
    d2 = (np.log(S / K) + (r - 0.5 * vol ** 2) * T) / (vol * np.sqrt(T))
    if payoff == "call":
        option_value = S * si.norm.cdf(d1, 0.0, 1.0) - K * np.exp(-r * T) * si.norm.cdf(d2, 0.0, 1.0)
    elif payoff == "put":
        option_value = - S * si.norm.cdf(-d1, 0.0, 1.0) + K * np.exp(-r * T) * si.norm.cdf(-d2, 0.0, 1.0)
    
    return option_value

# %%
s = 295
K = 305
T = 0.25   # 3 Months time period
r = 0.03
q = 0
vol=0.71

# %%
 euro_option_bs(s, K, T, r, vol, 'call')
# Out:
# 38.354524682589215

# %%
S = np.linspace(200,390,10)
cp = np.zeros((len(S),1))
for i in range(len(S)):
    cp[i] = euro_option_bs(S[i], 295, 0.25, 0.03, 0.71, 'call')

# %%
fig = plt.figure()
plt.plot(S, cp, '-')
plt.plot(S, np.maximum(S-295,0), '--')
plt.xlabel('Stock Price')
plt.ylabel('Price')
plt.title('European Call')
plt.legend(['Option Price','Payoff at T'])

# %%
def mcs_simulation_np(p):
    M = p
    I = p
    dt = T / M 
    S = np.zeros((M + 1, I))
    S[0] = S0 
    rn = np.random.standard_normal(S.shape) 
    for t in range(1, M + 1): 
        S[t] = S[t-1] * np.exp((r - sigma ** 2 / 2) * dt + sigma * np.sqrt(dt) * rn[t]) 
    return S

# %%
T = 0.25
r = 0.03
sigma = 0.71
S0 = 295
K = 305

# %%
S = mcs_simulation_np(1000)

# %%
S = np.transpose(S)
S
# Out:
# array([[295.        , 295.93924046, 300.2947884 , ..., 332.11590449,
#         325.65031937, 326.85263662],
#        [295.        , 296.94127603, 297.26900074, ..., 222.10397379,
#         223.79062018, 218.3444378 ],
#        [295.        , 296.79814983, 295.74697729, ..., 277.7254526 ,
#         278.30586345, 269.62668074],
#        ...,
#        [295.        , 294.06947454, 300.18114242, ..., 348.20346522,
#         347.39094749, 343.47669077],
#        [295.        , 296.98679   , 298.96361425, ..., 337.00550536,
#         341.19686016, 343.01634187],
#        [295.        , 286.39042571, 287.72388619, ..., 290.77641309,
#         293.63836552, 289.35796019]])

# %%
import matplotlib.pyplot as plt
n, bins, patches = plt.hist(x=S[:,-1], bins='auto', color='#0504aa',alpha=0.7, rwidth=0.85)

plt.grid(axis='y', alpha=0.75)
plt.xlabel('S_T')
plt.ylabel('Frequency')
plt.title('Frequency distribution of the simulated end-of-preiod values')
# Out:
# Text(0.5, 1.0, 'Frequency distribution of the simulated end-of-preiod values')

# %%
c = np.mean(np.maximum(S[:,-1] -K, 0))
print('European call', str(c))
# Out:
# European call 36.75910770685159

# %% [markdown]
# GREEK VARIABLES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as si

# %% [markdown]
# Delta

# %%
def delta(S, K, T, r, q, vol, payoff):
    
   
    d1 = (np.log(S / K) + (r - q + 0.5 * vol ** 2) * T) / (vol * np.sqrt(T))
    if payoff == "call":
        delta = np.exp(-q * T) * si.norm.cdf(d1, 0.0, 1.0)
    elif payoff == "put":
        delta =  -np.exp(-q * T) * si.norm.cdf(-d1, 0.0, 1.0)
    
    return delta

# %%
delta(295, 305, 0.25, 0.03, 0.0, 0.71, 'call')
# Out:
# 0.5417015404091364

# %% [markdown]
# #### Delta analyses the sensitivity of the option or portfolio to the underlying asset price. Delta of 0.54 implies that if the asset price increases from 295 to 305, call option value will increase by 0.54 dollar.

# %%
S = np.linspace(200,390,10)
Delta_Call = np.zeros((len(S),1))
Delta_Put = np.zeros((len(S),1))
for i in range(len(S)):
    Delta_Call [i] = delta(S[i], 295, 0.25, 0.03, 0, 0.71, 'call')

# %%
fig = plt.figure()
plt.plot(S, Delta_Call, '-')
plt.grid()
plt.xlabel('Stock price')
plt.ylabel('Delta')
plt.title('Delta')
plt.legend(['Delta for Call'])

# %% [markdown]
# Gamma

# %%
def gamma(S, K, T, r, q, vol, payoff):
    
    d1 = (np.log(S / K) + (r - q + 0.5 * vol ** 2) * T) / (vol * np.sqrt(T))
    gamma = np.exp(- q * T) * si.norm.pdf(d1, 0.0, 1.0) / (vol * S * np.sqrt(T))
    
    return gamma

# %%
gamma(295, 305, 0.25, 0.03, 0, 0.71, 'call')
# Out:
# 0.0037885963649048585

# %% [markdown]
# Gamma measures the change in Delta with respect to the change in the underlying asset price.. If the underlying asset price increases by 1 dollar, the delta will increase by 0.04. The Gamma always has a positive value.

# %%
S = np.linspace(200,390,10)
Gamma = np.zeros((len(S),1))
for i in range(len(S)):
    Gamma [i] = gamma(S[i], 295, 305, 0.03,0,  0.71, 'call')

# %%
fig = plt.figure()
plt.plot(S, Gamma, '-')
plt.grid()
plt.xlabel('Stock Price')
plt.ylabel('Gamma')
plt.title('Gamma')
plt.legend(['Gamma for Call'])

# %% [markdown]
# Speed

# %%
def speed(S, K, T, r, q, vol, payoff):
    
    d1 = (np.log(S / K) + (r - q + 0.5 * vol ** 2) * T) / (vol * np.sqrt(T))
    speed = - np.exp(-q * T) * si.norm.pdf(d1, 0.0, 1.0) / ((vol **2) * (S**2) * np.sqrt(T)) * (d1 + vol * np.sqrt(T))
    
    return speed

# %%
speed(295, 305, 0.25, 0.03, 0, 0.71, 'call')
# Out:
# -8.315581955729116e-06

# %% [markdown]
# ##### This is the first order derivative for gamma. It measures the rate of change of the gamma with respect to the change in te underling asset price. Where the underlying asset price increases from 295 to 395 then the gamma will decrease by 0.001

# %%
S = np.linspace(200,390,10)
Speed = np.zeros((len(S),1))
for i in range(len(S)):
    Speed [i] = speed(S[i], 295, 0.25, 0.03, 0, 0.71, 'call')

# %%
fig = plt.figure()
plt.plot(S, Speed, '-')
plt.grid()
plt.xlabel('Stock Price')
plt.ylabel('Speed')
plt.title('Speed')
plt.legend(['Speed for Call'])

# %% [markdown]
# Theta

# %%
def theta(S, K, T, r, q, vol, payoff):
    
    d1 = (np.log(S / K) + (r - q + 0.5 * vol ** 2) * T) / (vol * np.sqrt(T))
    d2 = (np.log(S / K) + (r - q - 0.5 * vol ** 2) * T) / (vol * np.sqrt(T))
    if payoff == "call":
        theta = vol * S * np.exp(-q * T) * si.norm.pdf(d1, 0.0, 1.0) / (2 * np.sqrt(T)) - q * S * np.exp(-q * T) * si.norm.cdf(d1, 0.0, 1.0) + r * K * np.exp(-r * T) * si.norm.cdf(d2, 0.0, 1.0)
    elif payoff == "put":
        theta = vol * S * np.exp(-q * T) * si.norm.pdf(-d1, 0.0, 1.0) / (2 * np.sqrt(T)) - q * S * np.exp(-q * T) * si.norm.cdf(-d1, 0.0, 1.0) + r * K * np.exp(-r * T) * si.norm.cdf(-d2, 0.0, 1.0)
    
    return theta

# %%
theta(295, 305, 0.25, 0.03, 0, 0.71, 'call')
# Out:
# 86.74496288334898

# %%
86.74496288334898/52
# Out:
# 1.6681723631413266

# %%
T = np.linspace(0.25,2,10)
Theta_Call = np.zeros((len(T),1))
Theta_Put = np.zeros((len(T),1))
for i in range(len(T)):
    Theta_Call [i] = theta(295, 305, T[i], 0.25, 0.03, 0.71, 'call')

# %%
fig = plt.figure()
plt.plot(T, Theta_Call, '-')
plt.grid()
plt.xlabel('Time to Expiry')
plt.ylabel('Theta')
plt.title('Theta')
plt.legend(['Theta for Call'])

# %% [markdown]
# RHO

# %%
def rho(S, K, T, r, q, vol, payoff):
    
    d1 = (np.log(S / K) + (r - q + 0.5 * vol ** 2) * T) / (vol * np.sqrt(T))
    d2 = (np.log(S / K) + (r - q - 0.5 * vol ** 2) * T) / (vol * np.sqrt(T))
    if payoff == "call":
        rho =  K * T * np.exp(-r * T) * si.norm.cdf(d2, 0.0, 1.0)
    elif payoff == "put":
        rho = - K * T * np.exp(-r * T) * si.norm.cdf(-d2, 0.0, 1.0)
    
    return rho

# %%
rho(295, 305, 0.25, 0.03, 0, 0.71, 'call')
# Out:
# 30.361857434526506

# %%
r = np.linspace(0,0.1,11)
Rho_Call = np.zeros((len(r),1))
for i in range(len(r)):
    Rho_Call [i] = rho(295, 305, 0.25, r[i], 0.03, 0.71, 'call')

# %%
fig = plt.figure()
plt.plot(r, Rho_Call, '-')
plt.grid()
plt.xlabel('Interest Rate')
plt.ylabel('Rho')
plt.title('Rho')
plt.legend(['Rho for Call',])
